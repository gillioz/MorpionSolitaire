# %% [markdown]
# # Part 3: A simple binary problem

# %% [markdown]
# To cover:
# - generate the data: use distribution for grids with possible moves
# - learn something: it is sufficient to check presence of a segment at both extremities

# %%
from graphviz import Digraph

# %%
graph = Digraph()
graph.node('0', label='94 x 94 grid')
graph.node('1', label='Convolutional layer, 13 x 13 kernel, stride 3', shape='box')
graph.node('2', label='Max pool', shape='box')
graph.node('3', label='Linear layer', shape='box')
graph.node('4', label='Linear layer', shape='box')
graph.edges(['01', '12','23','34'])
graph
