# %% [markdown]
# # Deep Learning Morpion Solitaire
#
# # Part 3: A simple classification problem

# %% [markdown]
# To cover:
# - generate the data: use distribution for grids with possible moves
# - learn something: it is sufficient to check presence of a segment at both extremities

# %%
from graphviz import Digraph

# %%
graph = Digraph()
graph.node('0', label='94 x 94 grid')
graph.node('1', label='ConvNet \n 13 x 13 kernel \n stride 3', shape='box')
graph.node('2', label='Max Pool')
graph.edges(['01', '12'])
graph
