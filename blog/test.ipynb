# %%
#hide
from PIL import Image

# %% [markdown]
# here some text

# %%
#hide
Image.open('../drawings/result_124.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x400 at 0x7F383CF66CD0>

# %% [markdown]
# next: an animated gif

# %%
#hide
Image.open('../drawings/animation_124.gif')
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=400x400 at 0x7F383CF5ABB0>
